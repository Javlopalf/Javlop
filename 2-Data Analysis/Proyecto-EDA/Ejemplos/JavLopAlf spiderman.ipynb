# %% [markdown]
# # La primera parte es la importación de las librerias necesarias para sacar los datos. Y la creación del Dataframe.

# %%
import pandas as pd 
import numpy as np
import requests
import csv

# %%
filename = 'C:\\Users\\lopez\\OneDrive\\Escritorio\\CTBPush\\TheBrigde2022\\2-Data Analysis\\Proyecto-EDA\Marvel_Comics.csv'
data = pd.read_csv(filename, index_col=0)

print(data)
# Out:
#                                                   active_years  \
# comic_name
# A Year of Marvels: April Infinite Comic (2016)          (2016)
# A Year of Marvels: August Infinite Comic (2016)         (2016)
# A Year of Marvels: February Infinite Comic (2016)       (2016)
# A Year of Marvels: July Infinite Comic (2016)           (2016)
# A Year of Marvels: June Infinite Comic (2016)           (2016)
# ...                                                        ...
# Ziggy Pig - Silly Seal Comics (2019)                    (2019)
# Zombie (2006)                                           (2006)
# Zombie (2006)                                           (2006)
# Zombie (2006)                                           (2006)
# Zombie (2006)                                           (2006)
#
#                                                                                          issue_title  \
# comic_name
# ...

# %%
marvel = pd.DataFrame(data)
marvel
# Out:
#                                                   active_years  \
# comic_name
# A Year of Marvels: April Infinite Comic (2016)          (2016)
# A Year of Marvels: August Infinite Comic (2016)         (2016)
# A Year of Marvels: February Infinite Comic (2016)       (2016)
# A Year of Marvels: July Infinite Comic (2016)           (2016)
# A Year of Marvels: June Infinite Comic (2016)           (2016)
# ...                                                        ...
# Ziggy Pig - Silly Seal Comics (2019)                    (2019)
# Zombie (2006)                                           (2006)
# Zombie (2006)                                           (2006)
# Zombie (2006)                                           (2006)
# Zombie (2006)                                           (2006)
#
#                                                                                          issue_title  \
# comic_name
# ...

# %% [markdown]
# # A partir de aquí he limpiado el dataset, sacando las colecciones  y datos que yo quería.
# Psd: Es muy larga esta parte.

# %%
spectacularSpiderman = marvel.iloc[22695:22728]
bueno = spectacularSpiderman.iloc[0:5]

bueno2=  spectacularSpiderman.iloc[6:8]

fusion2005 = pd.concat([bueno, bueno2])

spec2004= spectacularSpiderman.iloc[8:11]
spec20042= spectacularSpiderman.iloc[12:24]

fusion2004 = pd.concat([spec2004,spec20042])


spec2003 = spectacularSpiderman.iloc[25:28]
spec20032= spectacularSpiderman.iloc[29:]


fusion2003 = pd.concat([spec2003, spec20032])

fusion2003['Price']="$2.99"

# %%
aranaspecial=  marvel.iloc[22961:22962]
aranaspecial
# Out:
#                                               active_years  \
# comic_name
# Spider-Man & Arana Special: The Hunter (2006)       (2006)
#
#                                                                                     issue_title  \
# comic_name
# Spider-Man & Arana Special: The Hunter (2006)  Spider-Man & Arana Special: The Hunter (2006) #1
#
#                                                  publish_date  \
# comic_name
# Spider-Man & Arana Special: The Hunter (2006)  March 29, 2006
#
#                                                                                issue_description  \
# comic_name
# Spider-Man & Arana Special: The Hunter (2006)  It all ends and begins right here! Araña learn...
#
#                                                     penciler         writer  \
# comic_name
# Spider-Man & Arana Special: The Hunter (2006)  Jonboy Meyers  Tania Del Rio
#
#                                                   cover_artist  \
# comic_name
# ...

# %%
spidermanHT = marvel.iloc[22962:22963]
spidermanHT
# Out:
#                                                    active_years  \
# comic_name
# Spider-Man & the Human Torch in...Bahia De Los ...       (2009)
#
#                                                                                           issue_title  \
# comic_name
# Spider-Man & the Human Torch in...Bahia De Los ...  Spider-Man & the Human Torch in...Bahia De Los...
#
#                                                       publish_date  \
# comic_name
# Spider-Man & the Human Torch in...Bahia De Los ...  March 04, 2009
#
#                                                                                     issue_description  \
# comic_name
# Spider-Man & the Human Torch in...Bahia De Los ...  The Fantastic Four are going back to Puerto Ri...
#
#                                                     penciler      writer  \
# comic_name
# Spider-Man & the Human Torch in...Bahia De Los ...  Juan Doe  Tom Beland
#
#                                                    cover_artist  \
# ...

# %%
spidermanSC = marvel.iloc[22966:22970]
sp2010= spidermanSC.iloc[0:3]
sp2010
sp2009 = spidermanSC.iloc[3:]
sp2010
# Out:
#                                              active_years  \
# comic_name
# Spider-Man & the Secret Wars (2009 - 2010)  (2009 - 2010)
# Spider-Man & the Secret Wars (2009 - 2010)  (2009 - 2010)
# Spider-Man & the Secret Wars (2009 - 2010)  (2009 - 2010)
#
#                                                                        issue_title  \
# comic_name
# Spider-Man & the Secret Wars (2009 - 2010)  Spider-Man & the Secret Wars (2009) #4
# Spider-Man & the Secret Wars (2009 - 2010)  Spider-Man & the Secret Wars (2009) #3
# Spider-Man & the Secret Wars (2009 - 2010)  Spider-Man & the Secret Wars (2009) #2
#
#                                                  publish_date  \
# comic_name
# Spider-Man & the Secret Wars (2009 - 2010)     March 17, 2010
# Spider-Man & the Secret Wars (2009 - 2010)  February 10, 2010
# Spider-Man & the Secret Wars (2009 - 2010)   January 13, 2010
#
#                                                                             issue_description  \
# ...

# %%
spidylob = marvel.iloc[22981:22985]
spidylob['Price']='$2.99'
spidylob
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               active_years                       issue_title  \
# comic_name
# Spider-Man & Wolverine (2003)       (2003)  Spider-Man & Wolverine (2003) #4
# Spider-Man & Wolverine (2003)       (2003)  Spider-Man & Wolverine (2003) #3
# Spider-Man & Wolverine (2003)       (2003)  Spider-Man & Wolverine (2003) #2
# Spider-Man & Wolverine (2003)       (2003)  Spider-Man & Wolverine (2003) #1
#
#                                      publish_date  \
# comic_name
# Spider-Man & Wolverine (2003)   November 01, 2003
# Spider-Man & Wolverine (2003)    October 01, 2003
# ...

# %%
spiderman= marvel.iloc[22986:23033]
spiderman2004 = spiderman.iloc[0:1]
spiderman2004['Price']='$24.95'
spiderman2004

spiderman1998 = spiderman.iloc[1:13]
spiderman1998['Price']='$1.99'
spiderman1998

spiderman1997 = spiderman.iloc[13:25]
spiderman1997['Price']= '$1.95'
spiderman1997

spiderman1996 = spiderman.iloc[25:37]
spiderman1996['Price']='$1,95'
spiderman1996

spiderman1995 = spiderman.iloc[37:47]
spiderman1995['Price']='$1.99'
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# ...

# %%
spid1602= marvel.iloc[23115:23121]
spid1602b = spid1602.iloc[1:]
spid1602b2010= spid1602b.iloc[0:2]
spid1602b2010

spid1602b2009= spid1602b.iloc[2:]
spid1602b2010
# Out:
#                                 active_years                issue_title  \
# comic_name
# Spider-Man 1602 (2009 - 2010)  (2009 - 2010)  Spider-Man 1602 (2009) #5
# Spider-Man 1602 (2009 - 2010)  (2009 - 2010)  Spider-Man 1602 (2009) #4
#
#                                     publish_date  \
# comic_name
# Spider-Man 1602 (2009 - 2010)  February 17, 2010
# Spider-Man 1602 (2009 - 2010)   January 20, 2010
#
#                                                                issue_description  \
# comic_name
# Spider-Man 1602 (2009 - 2010)                                               None
# Spider-Man 1602 (2009 - 2010)  Osborne makes a deal with the desperate Henri ...
#
#                                     penciler       writer cover_artist  \
# comic_name
# Spider-Man 1602 (2009 - 2010)  Ramon Rosanas  Jeff Parker         None
# Spider-Man 1602 (2009 - 2010)  Ramon Rosanas  Jeff Parker         None
#
#                               Imprint  Format Rating   Price
# comic_name
# ...

# %%
spid2099= marvel.iloc[23122:23141]
spid20991996 = spid2099.iloc[0:7]
spid20991996['Price']='$1.95'
spid20991996
spid20991995 = spid2099.iloc[7:]
spid209919952 = spid20991995.iloc[0:5]
spid209919952['Price']='$1.95'
spid209919952

spid209919953 = pd.concat([spid20991995, spid209919952])
spid209919953
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                 active_years                 issue_title  \
# comic_name
# ...

# %%
spid2099esp = marvel.iloc[23206:23207]
spid2099esp['Price']='$5.95'
spid2099esp
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                         active_years  \
# comic_name
# Spider-Man 2099 Meets Spider-Man (1995)       (1995)
#
#                                                                         issue_title  \
# comic_name
# Spider-Man 2099 Meets Spider-Man (1995)  Spider-Man 2099 Meets Spider-Man (1995) #1
#
#                                               publish_date  \
# comic_name
# Spider-Man 2099 Meets Spider-Man (1995)  November 01, 1995
#
#                                                                          issue_description  \
# comic_name
# ...

# %%
espe2099= marvel.iloc[23207:23208]
espe2099['Price']='$3.95'
espe2099
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                active_years  \
# comic_name
# Spider-Man 2099 Special (1995)       (1995)
#
#                                                       issue_title  \
# comic_name
# Spider-Man 2099 Special (1995)  Spider-Man 2099 Special (1995) #1
#
#                                      publish_date  \
# comic_name
# Spider-Man 2099 Special (1995)  November 01, 1995
#
#                                                                 issue_description  \
# comic_name
# Spider-Man 2099 Special (1995)  A terrifying, anthropomorphic man-spider is ca...
#
# ...

# %%
spidmovie2 = marvel.iloc[23209:23210]
spidmovie2
# Out:
#                                active_years  \
# comic_name
# Spider-Man 2: The Movie (2004)       (2004)
#
#                                                       issue_title  \
# comic_name
# Spider-Man 2: The Movie (2004)  Spider-Man 2: The Movie (2004) #1
#
#                                  publish_date  \
# comic_name
# Spider-Man 2: The Movie (2004)  June 30, 2004
#
#                                                                 issue_description  \
# comic_name
# Spider-Man 2: The Movie (2004)  In this comic-book adaptation of the sequel to...
#
#                                penciler        writer cover_artist  \
# comic_name
# Spider-Man 2: The Movie (2004)     None  Staz Johnson         None
#
#                                          Imprint  Format       Rating   Price
# comic_name
# Spider-Man 2: The Movie (2004)   MARVEL UNIVERSE   Comic   MARVEL PSR   $3.50

# %%
SpidaPP = marvel.iloc[23212:23216]
SpidaPP2007 = SpidaPP.iloc[0:2]
SpidaPP2007

SpidaPP2006 = SpidaPP.iloc[2:]
SpidaPP2007
# Out:
#                                  active_years  \
# comic_name
# Spider-Man and Power Pack (2007)       (2007)
# Spider-Man and Power Pack (2007)       (2007)
#
#                                                           issue_title  \
# comic_name
# Spider-Man and Power Pack (2007)  Spider-Man and Power Pack (2007) #4
# Spider-Man and Power Pack (2007)  Spider-Man and Power Pack (2007) #3
#
#                                        publish_date  \
# comic_name
# Spider-Man and Power Pack (2007)  February 07, 2007
# Spider-Man and Power Pack (2007)   January 03, 2007
#
#                                                                   issue_description  \
# comic_name
# Spider-Man and Power Pack (2007)  It's siblings vs. symbiotes as Spider-Man and ...
# Spider-Man and Power Pack (2007)  New York City isn't just the center of the Mar...
#
#                                  penciler writer cover_artist  \
# comic_name
# Spider-Man and Power Pack (2007)     None   None         None
# ...

# %%
spiderf4 = marvel.iloc[23217:23221]
spiderf4
# Out:
#                                          active_years  \
# comic_name
# Spider-Man and the Fantastic Four (2007)       (2007)
# Spider-Man and the Fantastic Four (2007)       (2007)
# Spider-Man and the Fantastic Four (2007)       (2007)
# Spider-Man and the Fantastic Four (2007)       (2007)
#
#                                                                           issue_title  \
# comic_name
# Spider-Man and the Fantastic Four (2007)  Spider-Man and the Fantastic Four (2007) #4
# Spider-Man and the Fantastic Four (2007)  Spider-Man and the Fantastic Four (2007) #3
# Spider-Man and the Fantastic Four (2007)  Spider-Man and the Fantastic Four (2007) #2
# Spider-Man and the Fantastic Four (2007)  Spider-Man and the Fantastic Four (2007) #1
#
#                                              publish_date  \
# comic_name
# Spider-Man and the Fantastic Four (2007)  August 01, 2007
# Spider-Man and the Fantastic Four (2007)    June 20, 2007
# ...

# %%
spiderftales= marvel.iloc[23224:23228]
spiderftales['Price']='$2.99'
spiderftales
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               active_years                       issue_title  \
# comic_name
# Spider-Man Fairy Tales (2007)       (2007)  Spider-Man Fairy Tales (2007) #4
# Spider-Man Fairy Tales (2007)       (2007)  Spider-Man Fairy Tales (2007) #3
# Spider-Man Fairy Tales (2007)       (2007)  Spider-Man Fairy Tales (2007) #2
# Spider-Man Fairy Tales (2007)       (2007)  Spider-Man Fairy Tales (2007) #1
#
#                                      publish_date  \
# comic_name
# Spider-Man Fairy Tales (2007)    October 12, 2007
# Spider-Man Fairy Tales (2007)  September 25, 2007
# ...

# %%
spiderfamily = marvel.iloc[23229:23239]
spiderfamily2008= spiderfamily.iloc[0:3]
spiderfamily2008

spiderfamily200725 = spiderfamily.iloc[3:]
spiderfamily20072 = spiderfamily200725.iloc[0:2]
spiderfamily20073 = spiderfamily200725.iloc[3:]
spiderfamily2007 = pd.concat([spiderfamily20072, spiderfamily20073])
spiderfamily2007
# Out:
#                                   active_years                  issue_title  \
# comic_name
# Spider-Man Family (2007 - 2008)  (2007 - 2008)  Spider-Man Family (2007) #6
# Spider-Man Family (2007 - 2008)  (2007 - 2008)  Spider-Man Family (2007) #5
# Spider-Man Family (2007 - 2008)  (2007 - 2008)  Spider-Man Family (2007) #4
# Spider-Man Family (2007 - 2008)  (2007 - 2008)  Spider-Man Family (2007) #3
# Spider-Man Family (2007 - 2008)  (2007 - 2008)  Spider-Man Family (2007) #2
# Spider-Man Family (2007 - 2008)  (2007 - 2008)  Spider-Man Family (2007) #1
#
#                                       publish_date  \
# comic_name
# Spider-Man Family (2007 - 2008)  December 12, 2007
# Spider-Man Family (2007 - 2008)   October 17, 2007
# Spider-Man Family (2007 - 2008)    August 15, 2007
# Spider-Man Family (2007 - 2008)      June 06, 2007
# Spider-Man Family (2007 - 2008)     April 04, 2007
# Spider-Man Family (2007 - 2008)  February 21, 2007
#
# ...

# %%
spidermanff = marvel.iloc[23240:23241]
spidermanff
# Out:
#                                                    active_years  \
# comic_name
# Spider-Man Family Featuring Spider-Man's Amazin...       (2006)
#
#                                                                                           issue_title  \
# comic_name
# Spider-Man Family Featuring Spider-Man's Amazin...  Spider-Man Family Featuring Spider-Man's Amazi...
#
#                                                        publish_date  \
# comic_name
# Spider-Man Family Featuring Spider-Man's Amazin...  August 09, 2006
#
#                                                                                     issue_description  \
# comic_name
# Spider-Man Family Featuring Spider-Man's Amazin...  Celebrating the 25th anniversary of the classi...
#
#                                                                                          penciler  \
# comic_name
# Spider-Man Family Featuring Spider-Man's Amazin...  Chris Giarrusso, Patrick Olliffe, Casey Jones
#
# ...

# %%
spidmj1 = marvel.iloc[23247:23271]
spidmj1['Price']='$2.99'


spidmj12005 = spidmj1.iloc[23:24]
spidmj12005

spidmj120071= spidmj1.iloc[1:9]
spidmj1200711 = spidmj120071.iloc[0:2]
spidmj1200721 = spidmj120071.iloc[4:]
spidmj1200721

spidmj12007 = pd.concat([spidmj1200711, spidmj1200721])
spidmj12007

spidmj120061 = spidmj1.iloc[10:23]
spidmj120062 = spidmj120061.iloc[0:6]
spidmj120063 = spidmj120061.iloc[7:]
spidmj120063

spidmj12006 = pd.concat([spidmj120062, spidmj120063])
#spidmj12006
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
spidmj2 = marvel.iloc[23271:23276]
spidmj2
# Out:
#                                            active_years  \
# comic_name
# Spider-Man Loves Mary Jane (2008 - 2009)  (2008 - 2009)
# Spider-Man Loves Mary Jane (2008 - 2009)  (2008 - 2009)
# Spider-Man Loves Mary Jane (2008 - 2009)  (2008 - 2009)
# Spider-Man Loves Mary Jane (2008 - 2009)  (2008 - 2009)
# Spider-Man Loves Mary Jane (2008 - 2009)  (2008 - 2009)
#
#                                                                    issue_title  \
# comic_name
# Spider-Man Loves Mary Jane (2008 - 2009)  Spider-Man Loves Mary Jane (2008) #5
# Spider-Man Loves Mary Jane (2008 - 2009)  Spider-Man Loves Mary Jane (2008) #4
# Spider-Man Loves Mary Jane (2008 - 2009)  Spider-Man Loves Mary Jane (2008) #3
# Spider-Man Loves Mary Jane (2008 - 2009)  Spider-Man Loves Mary Jane (2008) #2
# Spider-Man Loves Mary Jane (2008 - 2009)  Spider-Man Loves Mary Jane (2008) #1
#
#                                                 publish_date  \
# comic_name
# ...

# %%
spiderMA = marvel.iloc[23291:23315]
spiderMA2012= spiderMA.iloc[0:3]
spiderMA2012
spiderMA2011= spiderMA.iloc[3:15]
spiderMA2011
spiderMA2010 = spiderMA.iloc[15:]
#spiderMA2012

# %%
Spidernoir= marvel.iloc[23315:23319]
Spidernoir2009= Spidernoir.iloc[0:2]
Spidernoir2009
spidernoir2008 = Spidernoir.iloc[2:]
#spidernoir2008

# %%
Spidernoirface= marvel.iloc[23324:23328]
Spidernoirface2010= Spidernoirface.iloc[0:3]
Spidernoirface2010

Spidernoirface2009= Spidernoirface.iloc[3:]
#Spidernoirface2010

# %%
spidSPBL = marvel.iloc[23329:23330]
spidSPBL
# Out:
#                                                    active_years  \
# comic_name
# Spider-Man Special: Black and Blue and Read All...       (2006)
#
#                                                                                           issue_title  \
# comic_name
# Spider-Man Special: Black and Blue and Read All...  Spider-Man Special: Black and Blue and Read Al...
#
#                                                           publish_date  \
# comic_name
# Spider-Man Special: Black and Blue and Read All...  September 06, 2006
#
#                                                                                     issue_description  \
# comic_name
# Spider-Man Special: Black and Blue and Read All...  A special stand-alone story set in the recent ...
#
#                                                         penciler       writer  \
# comic_name
# Spider-Man Special: Black and Blue and Read All...  Drew Johnson  Jim Krueger
#
# ...

# %%
spidTeamup= marvel.iloc[23331:23337]
spidTeamup['Price']='$2.95'

spidTeamup1997 = spidTeamup[0:1]
spidTeamup1997

spidTeamup1996 = spidTeamup.iloc[1:5]
spidTeamup1996

spidTeamup1995 = spidTeamup.iloc[5:]
#spidTeamup1995
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
teamup = marvel.iloc[23337:23340]
teamup['Price']= '$2.99'
teamup
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                    active_years  \
# comic_name
# Spider-Man Team-Up Special (2005)                        (2005)
# Spider-Man Team-Up Special (2005)                        (2005)
# SPIDER-MAN TEAM-UP VOL. 1: A LITTLE HELP FROM M...       (2005)
#
#                                                                                           issue_title  \
# comic_name
# Spider-Man Team-Up Special (2005)                                Spider-Man Team-Up Special (2005) #1
# ...

# %%
spidunlit= marvel.iloc[23351:23367]
spidunlit['Price']='$2.99'
spidunlit2006 = spidunlit[0:3]
spidunlit2006

spidunlit2005= spidunlit[3:10]

spidunlit2004= spidunlit[10:]
spidunlit2006
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                      active_years  \
# comic_name
# Spider-Man Unlimited (2004 - 2006)  (2004 - 2006)
# Spider-Man Unlimited (2004 - 2006)  (2004 - 2006)
# Spider-Man Unlimited (2004 - 2006)  (2004 - 2006)
#
#                                                         issue_title  \
# comic_name
# Spider-Man Unlimited (2004 - 2006)  Spider-Man Unlimited (2004) #15
# Spider-Man Unlimited (2004 - 2006)  Spider-Man Unlimited (2004) #14
# Spider-Man Unlimited (2004 - 2006)  Spider-Man Unlimited (2004) #13
#
#                                         publish_date  \
# comic_name
# ...

# %%
spidvspu = marvel.iloc[23368:23369]
spidvspu['Price']='$2.99'
spidvspu
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                active_years  \
# comic_name
# Spider-Man Vs. Punisher (2000)       (2000)
#
#                                                       issue_title  \
# comic_name
# Spider-Man Vs. Punisher (2000)  Spider-Man Vs. Punisher (2000) #1
#
#                                  publish_date  \
# comic_name
# Spider-Man Vs. Punisher (2000)  July 01, 2000
#
#                                                                 issue_description  \
# comic_name
# Spider-Man Vs. Punisher (2000)  The mystery man with a skull on his chest has ...
#
# ...

# %%
spidvamp =marvel.iloc[23369:23370]
spidvamp
# Out:
#                                active_years  \
# comic_name
# Spider-Man vs. Vampires (2010)       (2010)
#
#                                                       issue_title  \
# comic_name
# Spider-Man vs. Vampires (2010)  Spider-Man vs. Vampires (2010) #1
#
#                                     publish_date  \
# comic_name
# Spider-Man vs. Vampires (2010)  October 27, 2010
#
#                                                                 issue_description  \
# comic_name
# Spider-Man vs. Vampires (2010)  VAMPIRES! You can't trust them, even when they...
#
#                                penciler writer cover_artist Imprint  Format  \
# comic_name
# Spider-Man vs. Vampires (2010)     None   None         None    None   Comic
#
#                                    Rating   Price
# comic_name
# Spider-Man vs. Vampires (2010)   Rated T+   $3.99

# %%
spidTW1 = marvel.iloc[23370:23395]
spidTW2 = spidTW1.iloc[0:2]
spidTW22= spidTW1.iloc[3:5]
spidTW23 = spidTW1.iloc[6:18]
spidTW24 = spidTW1.iloc[19:]
spidTW24

spidTW = pd.concat([spidTW2,spidTW22, spidTW23, spidTW24])
spidTW['Price']='$2.99'

spidTW2003 = spidTW.iloc[0:3]
spidTW2003

spidTW2002= spidTW.iloc[3:16]
spidTW2002

spidTW2001 = spidTW.iloc[15:]
spidTW2003
# Out:
#                                          active_years  \
# comic_name
# Spider-Man's Tangled Web (2001 - 2003)  (2001 - 2003)
# Spider-Man's Tangled Web (2001 - 2003)  (2001 - 2003)
# Spider-Man's Tangled Web (2001 - 2003)  (2001 - 2003)
#
#                                                                 issue_title  \
# comic_name
# Spider-Man's Tangled Web (2001 - 2003)  Spider-Man's Tangled Web (2001) #22
# Spider-Man's Tangled Web (2001 - 2003)  Spider-Man's Tangled Web (2001) #21
# Spider-Man's Tangled Web (2001 - 2003)  Spider-Man's Tangled Web (2001) #20
#
#                                              publish_date  \
# comic_name
# Spider-Man's Tangled Web (2001 - 2003)     March 01, 2003
# Spider-Man's Tangled Web (2001 - 2003)  February 01, 2003
# Spider-Man's Tangled Web (2001 - 2003)   January 01, 2003
#
#                                                                         issue_description  \
# comic_name
# ...

# %%
peterBB = marvel.iloc[23396:23397]
peterBB['Price']='$9.99'
peterBB
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                active_years  \
# comic_name
# Spider-Man, Peter Parker: Back in Black (2007)       (2007)
#
#                                                                                    issue_title  \
# comic_name
# Spider-Man, Peter Parker: Back in Black (2007)  Spider-Man, Peter Parker: Back in Black (2007)
#
#                                                      publish_date  \
# comic_name
# Spider-Man, Peter Parker: Back in Black (2007)  November 14, 2007
#
# ...

# %%
spBC= marvel.iloc[23398:23404]
spBC['Price']='$2.99'
spBC2006 = spBC.iloc[0:1]
spBC2006
spBC2005 = spBC.iloc[2:5]
spBC2005
spBC2002 = spBC.iloc[4:]
#spBC2006
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Spiddad= marvel.iloc[23404:23405]
Spiddad['Price']='$2.99'
Spiddad
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             active_years                     issue_title  \
# comic_name
# Spider-Man/Daredevil (2002)       (2002)  Spider-Man/Daredevil (2002) #1
#
#                                  publish_date  \
# comic_name
# Spider-Man/Daredevil (2002)  October 01, 2002
#
#                                                              issue_description  \
# comic_name
# Spider-Man/Daredevil (2002)  Two of New York City's favorite masked, crime-...
#
#                                    penciler          writer cover_artist  \
# comic_name
# ...

# %%
octopusneg= marvel.iloc[23456:23462]
octopusneg1 = octopusneg.iloc[1:]
octopusneg1['Price']='$2.99'
octopusneg12004 = octopusneg1.iloc[0:2]
octopusneg12004
octopusneg12003 = octopusneg1.iloc[2:]
octopusneg12003
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                      active_years  \
# comic_name
# Spider-Man/Doctor Octopus: Negative Exposure (2...  (2003 - 2004)
# Spider-Man/Doctor Octopus: Negative Exposure (2...  (2003 - 2004)
# Spider-Man/Doctor Octopus: Negative Exposure (2...  (2003 - 2004)
#
#                                                                                           issue_title  \
# comic_name
# Spider-Man/Doctor Octopus: Negative Exposure (2...  Spider-Man/Doctor Octopus: Negative Exposure (...
# ...

# %%
octopusreach = marvel.iloc[23462:23467]
octopusreach['Price']='$2.99'
octopusreach
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                active_years  \
# comic_name
# Spider-Man/Doctor Octopus: Out of Reach (2004)       (2004)
# Spider-Man/Doctor Octopus: Out of Reach (2004)       (2004)
# Spider-Man/Doctor Octopus: Out of Reach (2004)       (2004)
# Spider-Man/Doctor Octopus: Out of Reach (2004)       (2004)
# Spider-Man/Doctor Octopus: Out of Reach (2004)       (2004)
#
#                                                                                       issue_title  \
# comic_name
# Spider-Man/Doctor Octopus: Out of Reach (2004)  Spider-Man/Doctor Octopus: Out of Reach (2004) #5
# ...

# %%
OctopusY1= marvel.iloc[23468:23473]
OctopusY1
# Out:
#                                            active_years  \
# comic_name
# Spider-Man/Doctor Octopus: Year One (2004)       (2004)
# Spider-Man/Doctor Octopus: Year One (2004)       (2004)
# Spider-Man/Doctor Octopus: Year One (2004)       (2004)
# Spider-Man/Doctor Octopus: Year One (2004)       (2004)
# Spider-Man/Doctor Octopus: Year One (2004)       (2004)
#
#                                                                               issue_title  \
# comic_name
# Spider-Man/Doctor Octopus: Year One (2004)  Spider-Man/Doctor Octopus: Year One (2004) #5
# Spider-Man/Doctor Octopus: Year One (2004)  Spider-Man/Doctor Octopus: Year One (2004) #4
# Spider-Man/Doctor Octopus: Year One (2004)  Spider-Man/Doctor Octopus: Year One (2004) #3
# Spider-Man/Doctor Octopus: Year One (2004)  Spider-Man/Doctor Octopus: Year One (2004) #2
# Spider-Man/Doctor Octopus: Year One (2004)  Spider-Man/Doctor Octopus: Year One (2004) #1
#
# ...

# %%
spiderFF2 = marvel.iloc[23474:23478]
spiderFF2
# Out:
#                                  active_years  \
# comic_name
# Spider-Man/Fantastic Four (2010)       (2010)
# Spider-Man/Fantastic Four (2010)       (2010)
# Spider-Man/Fantastic Four (2010)       (2010)
# Spider-Man/Fantastic Four (2010)       (2010)
#
#                                                           issue_title  \
# comic_name
# Spider-Man/Fantastic Four (2010)  Spider-Man/Fantastic Four (2010) #4
# Spider-Man/Fantastic Four (2010)  Spider-Man/Fantastic Four (2010) #3
# Spider-Man/Fantastic Four (2010)  Spider-Man/Fantastic Four (2010) #2
# Spider-Man/Fantastic Four (2010)  Spider-Man/Fantastic Four (2010) #1
#
#                                         publish_date  \
# comic_name
# Spider-Man/Fantastic Four (2010)    October 27, 2010
# Spider-Man/Fantastic Four (2010)  September 15, 2010
# Spider-Man/Fantastic Four (2010)     August 04, 2010
# Spider-Man/Fantastic Four (2010)       July 08, 2010
#
# ...

# %%
spiderHT= marvel.iloc[23480:23485]
spiderHT
# Out:
#                               active_years                       issue_title  \
# comic_name
# Spider-Man/Human Torch (2005)       (2005)  Spider-Man/Human Torch (2005) #5
# Spider-Man/Human Torch (2005)       (2005)  Spider-Man/Human Torch (2005) #4
# Spider-Man/Human Torch (2005)       (2005)  Spider-Man/Human Torch (2005) #3
# Spider-Man/Human Torch (2005)       (2005)  Spider-Man/Human Torch (2005) #2
# Spider-Man/Human Torch (2005)       (2005)  Spider-Man/Human Torch (2005) #1
#
#                                     publish_date  \
# comic_name
# Spider-Man/Human Torch (2005)      June 29, 2005
# Spider-Man/Human Torch (2005)       May 11, 2005
# Spider-Man/Human Torch (2005)     March 23, 2005
# Spider-Man/Human Torch (2005)  February 23, 2005
# Spider-Man/Human Torch (2005)   January 05, 2005
#
#                                                                issue_description  \
# comic_name
# Spider-Man/Human Torch (2005)  Peter Parker might be the coolest teacher in s...
# ...

# %%
famspidpu= marvel.iloc[23486:23487]
famspidpu['Price']='$2.95'
famspidpu
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                         active_years  \
# comic_name
# Spider-Man/Punisher: Family Plot (1996)       (1996)
#
#                                                                         issue_title  \
# comic_name
# Spider-Man/Punisher: Family Plot (1996)  Spider-Man/Punisher: Family Plot (1996) #1
#
#                                               publish_date  \
# comic_name
# Spider-Man/Punisher: Family Plot (1996)  February 01, 1996
#
#                                                                          issue_description  \
# comic_name
# ...

# %%
redsonja= marvel.iloc[23487:23492]
redsonja
# Out:
#                             active_years                     issue_title  \
# comic_name
# Spider-Man/Red Sonja (2007)       (2007)  Spider-Man/Red Sonja (2007) #5
# Spider-Man/Red Sonja (2007)       (2007)  Spider-Man/Red Sonja (2007) #4
# Spider-Man/Red Sonja (2007)       (2007)  Spider-Man/Red Sonja (2007) #3
# Spider-Man/Red Sonja (2007)       (2007)  Spider-Man/Red Sonja (2007) #2
# Spider-Man/Red Sonja (2007)       (2007)  Spider-Man/Red Sonja (2007) #1
#
#                                    publish_date  \
# comic_name
# Spider-Man/Red Sonja (2007)   December 12, 2007
# Spider-Man/Red Sonja (2007)   November 14, 2007
# Spider-Man/Red Sonja (2007)    October 10, 2007
# Spider-Man/Red Sonja (2007)  September 19, 2007
# Spider-Man/Red Sonja (2007)     August 01, 2007
#
#                                                              issue_description  \
# comic_name
# Spider-Man/Red Sonja (2007)  Swords vs. webs - the final battle! Spider-Man...
# ...

# %%
spid101= marvel.iloc[23492:23493]
spid101['Price']='$2.50'
spid101
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                   active_years  \
# comic_name
# Spider-Man: 101 Ways to End the Clone Saga (1997)       (1997)
#
#                                                                                          issue_title  \
# comic_name
# Spider-Man: 101 Ways to End the Clone Saga (1997)  Spider-Man: 101 Ways to End the Clone Saga (19...
#
#                                                        publish_date  \
# comic_name
# Spider-Man: 101 Ways to End the Clone Saga (1997)  January 01, 1997
#
# ...

# %%
spidBB2= marvel.iloc[23493:23494]
spidBB2
# Out:
#                                  active_years  \
# comic_name
# Spider-Man: Back in Black (2007)       (2007)
#
#                                                           issue_title  \
# comic_name
# Spider-Man: Back in Black (2007)  Spider-Man: Back in Black (2007) #2
#
#                                     publish_date issue_description  \
# comic_name
# Spider-Man: Back in Black (2007)  April 11, 2007              None
#
#                                         penciler  \
# comic_name
# Spider-Man: Back in Black (2007)  Aaron Lopresti
#
#                                                                              writer  \
# comic_name
# Spider-Man: Back in Black (2007)  Stuart Vandal, Mike Fichera, Sean Mcquaid, Mad...
#
#                                  cover_artist           Imprint  Format  \
# comic_name
# Spider-Man: Back in Black (2007)         None   MARVEL UNIVERSE   Comic
#
#                                  Rating   Price
# comic_name
# ...

# %%
spidBIQ= marvel.iloc[23494:23495]
spidBIQ
# Out:
#                                  active_years  \
# comic_name
# Spider-Man: Back in Quack (2010)       (2010)
#
#                                                           issue_title  \
# comic_name
# Spider-Man: Back in Quack (2010)  Spider-Man: Back in Quack (2010) #1
#
#                                       publish_date  \
# comic_name
# Spider-Man: Back in Quack (2010)  October 06, 2010
#
#                                                                   issue_description  \
# comic_name
# Spider-Man: Back in Quack (2010)  Howard the Duck's brain has been thoroughly sc...
#
#                                                        penciler        writer  \
# comic_name
# Spider-Man: Back in Quack (2010)  Mark Brooks, JOSEPH J. SUITOR  Stuart Moore
#
#                                  cover_artist Imprint  Format Rating   Price
# comic_name
# Spider-Man: Back in Quack (2010)         None    None   Comic   None   $3.99

# %%
spidblue= marvel.iloc[23496:23502]
spidblue['Price']= '$3.50'
spidblue2003 = spidblue.iloc[0:1]
spidblue2003
spidblue2002= spidblue.iloc[1:]
spidblue2003
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                  active_years                 issue_title  \
# comic_name
# Spider-Man: Blue (2002 - 2003)  (2002 - 2003)  Spider-Man: Blue (2002) #6
#
#                                   publish_date  \
# comic_name
# Spider-Man: Blue (2002 - 2003)  April 10, 2003
#
#                                                                 issue_description  \
# comic_name
# Spider-Man: Blue (2002 - 2003)  The shadowy figure that has orchestrated Spide...
#
#                                 penciler     writer cover_artist Imprint  \
# comic_name
# ...

# %%
brand= marvel.iloc[23502:23509]
brand2009 = brand.iloc[0:2]
brand2009
brand2008 = brand.iloc[2:]
brand2009
# Out:
#                                           active_years  \
# comic_name
# Spider-Man: Brand New Day (2008 - 2009)  (2008 - 2009)
# Spider-Man: Brand New Day (2008 - 2009)  (2008 - 2009)
#
#                                                                  issue_title  \
# comic_name
# Spider-Man: Brand New Day (2008 - 2009)  Spider-Man: Brand New Day (2008) #5
# Spider-Man: Brand New Day (2008 - 2009)  Spider-Man: Brand New Day (2008) #4
#
#                                               publish_date  \
# comic_name
# Spider-Man: Brand New Day (2008 - 2009)  February 11, 2009
# Spider-Man: Brand New Day (2008 - 2009)   January 14, 2009
#
#                                                                          issue_description  \
# comic_name
# Spider-Man: Brand New Day (2008 - 2009)  AMAZING SPIDER-MAN #554\nAMAZING SPIDER-MAN #5...
# Spider-Man: Brand New Day (2008 - 2009)  AMAZING SPIDER-MAN #552\nAMAZING SPIDER-MAN #5...
#
# ...

# %%
breakout= marvel.iloc[23510:23515]
breakout['Price']='$2.99'
breakout
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             active_years                     issue_title  \
# comic_name
# Spider-Man: Breakout (2005)       (2005)  Spider-Man: Breakout (2005) #5
# Spider-Man: Breakout (2005)       (2005)  Spider-Man: Breakout (2005) #3
# Spider-Man: Breakout (2005)       (2005)  Spider-Man: Breakout (2005) #4
# Spider-Man: Breakout (2005)       (2005)  Spider-Man: Breakout (2005) #2
# Spider-Man: Breakout (2005)       (2005)  Spider-Man: Breakout (2005) #1
#
#                                 publish_date  \
# comic_name
# Spider-Man: Breakout (2005)  August 10, 2005
# ...

# %%
chapter10= marvel.iloc[23515:23528]
chapter1 = chapter10.iloc[0:5]
chapter1
chapter2= chapter10.iloc[6:]
chapter2 
chapter = pd.concat([chapter1, chapter2])
chapter['Price']='$2.50'
chapter

chapter99= chapter.iloc[0:10]
chapter99
chapter98= chapter.iloc[10:]
chapter99
# Out:
#                                         active_years  \
# comic_name
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
# Spider-Man: Chapter One (1998 - 1999)  (1998 - 1999)
#
#                                                               issue_title  \
# comic_name
# Spider-Man: Chapter One (1998 - 1999)  Spider-Man: Chapter One (1998) #12
# Spider-Man: Chapter One (1998 - 1999)  Spider-Man: Chapter One (1998) #11
# Spider-Man: Chapter One (1998 - 1999)  Spider-Man: Chapter One (1998) #10
# ...

# %%
spidDMH= marvel.iloc[23529:23530]
spidDMH['Price']= '$2.99'
spidDMH
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    active_years  \
# comic_name
# Spider-Man: Dead Man's Hand (1997)       (1997)
#
#                                                               issue_title  \
# comic_name
# Spider-Man: Dead Man's Hand (1997)  Spider-Man: Dead Man's Hand (1997) #1
#
#                                       publish_date  \
# comic_name
# Spider-Man: Dead Man's Hand (1997)  April 01, 1997
#
#                                                                     issue_description  \
# comic_name
# Spider-Man: Dead Man's Hand (1997)  The resurrection of Carrion! In this double-si...
#
# ...

# %%
spidDDes= marvel.iloc[23530:23533]
spidDDes['Price']='$2.99'
spidDDes
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                      active_years  \
# comic_name
# Spider-Man: Death and Destiny (2000)       (2000)
# Spider-Man: Death and Destiny (2000)       (2000)
# Spider-Man: Death and Destiny (2000)       (2000)
#
#                                                                   issue_title  \
# comic_name
# Spider-Man: Death and Destiny (2000)  Spider-Man: Death and Destiny (2000) #3
# Spider-Man: Death and Destiny (2000)  Spider-Man: Death and Destiny (2000) #2
# Spider-Man: Death and Destiny (2000)  Spider-Man: Death and Destiny (2000) #1
#
# ...

# %%
fearitself= marvel.iloc[23536:23537]
fearitself
# Out:
#                                active_years  \
# comic_name
# Spider-Man: Fear Itself (2009)       (2009)
#
#                                                       issue_title  \
# comic_name
# Spider-Man: Fear Itself (2009)  Spider-Man: Fear Itself (2009) #1
#
#                                     publish_date  \
# comic_name
# Spider-Man: Fear Itself (2009)  January 07, 2009
#
#                                                                 issue_description  \
# comic_name
# Spider-Man: Fear Itself (2009)  The mucky man monster returns to meet the Amaz...
#
#                                   penciler        writer cover_artist  \
# comic_name
# Spider-Man: Fear Itself (2009)  JOE SUITOR  Stuart Moore         None
#
#                                          Imprint  Format    Rating   Price
# comic_name
# Spider-Man: Fear Itself (2009)   MARVEL UNIVERSE   Comic   RATED A   $3.99

# %%
fever= marvel.iloc[23537:23540]
fever['Price']='$3.99'
fever
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          active_years                  issue_title  \
# comic_name
# Spider-Man: Fever (2010)       (2010)  Spider-Man: Fever (2010) #3
# Spider-Man: Fever (2010)       (2010)  Spider-Man: Fever (2010) #2
# Spider-Man: Fever (2010)       (2010)  Spider-Man: Fever (2010) #1
#
#                             publish_date  \
# comic_name
# Spider-Man: Fever (2010)   June 09, 2010
# Spider-Man: Fever (2010)    May 05, 2010
# Spider-Man: Fever (2010)  April 07, 2010
#
#                                                           issue_description  \
# comic_name
# ...

# %%
getkraven= marvel.iloc[23540:23546]
getkraven['Price']='$2.99'
getkraven
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                        active_years  \
# comic_name
# Spider-Man: Get Kraven (2002 - 2003)  (2002 - 2003)
# Spider-Man: Get Kraven (2002 - 2003)  (2002 - 2003)
# Spider-Man: Get Kraven (2002 - 2003)  (2002 - 2003)
# Spider-Man: Get Kraven (2002 - 2003)  (2002 - 2003)
# Spider-Man: Get Kraven (2002 - 2003)  (2002 - 2003)
# Spider-Man: Get Kraven (2002 - 2003)  (2002 - 2003)
#
#                                                            issue_title  \
# comic_name
# Spider-Man: Get Kraven (2002 - 2003)  Spider-Man: Get Kraven (2002) #6
# ...

# %%
kravensaga= marvel.iloc[23546:23547]
kravensaga['Price']='$1.00'
kravensaga
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                active_years  \
# comic_name
# Spider-Man: Grim Hunt - The Kraven Saga (2010)       (2010)
#
#                                                                                       issue_title  \
# comic_name
# Spider-Man: Grim Hunt - The Kraven Saga (2010)  Spider-Man: Grim Hunt - The Kraven Saga (2010) #1
#
#                                                   publish_date  \
# comic_name
# Spider-Man: Grim Hunt - The Kraven Saga (2010)  April 14, 2010
#
#                                                issue_description  \
# comic_name
# ...

# %%
hobgoblin= marvel.iloc[23547:23550]
hobgoblin['Price']='$2.50'
hobgoblin
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    active_years  \
# comic_name
# Spider-Man: Hobgoblin Lives (1997)       (1997)
# Spider-Man: Hobgoblin Lives (1997)       (1997)
# Spider-Man: Hobgoblin Lives (1997)       (1997)
#
#                                                               issue_title  \
# comic_name
# Spider-Man: Hobgoblin Lives (1997)  Spider-Man: Hobgoblin Lives (1997) #3
# Spider-Man: Hobgoblin Lives (1997)  Spider-Man: Hobgoblin Lives (1997) #2
# Spider-Man: Hobgoblin Lives (1997)  Spider-Man: Hobgoblin Lives (1997) #1
#
#                                          publish_date  \
# ...

# %%
houseM= marvel.iloc[23551:23556]
houseM
# Out:
#                               active_years                       issue_title  \
# comic_name
# Spider-Man: House of M (2005)       (2005)  Spider-Man: House of M (2005) #5
# Spider-Man: House of M (2005)       (2005)  Spider-Man: House of M (2005) #4
# Spider-Man: House of M (2005)       (2005)  Spider-Man: House of M (2005) #3
# Spider-Man: House of M (2005)       (2005)  Spider-Man: House of M (2005) #2
# Spider-Man: House of M (2005)       (2005)  Spider-Man: House of M (2005) #1
#
#                                      publish_date  \
# comic_name
# Spider-Man: House of M (2005)   November 02, 2005
# Spider-Man: House of M (2005)  September 28, 2005
# Spider-Man: House of M (2005)     August 17, 2005
# Spider-Man: House of M (2005)       July 20, 2005
# Spider-Man: House of M (2005)       June 22, 2005
#
#                                                                issue_description  \
# comic_name
# ...

# %%
india= marvel.iloc[23557:23561]
india
# Out:
#                                   active_years                  issue_title  \
# comic_name
# Spider-Man: India (2004 - 2005)  (2004 - 2005)  Spider-Man: India (2004) #4
# Spider-Man: India (2004 - 2005)  (2004 - 2005)  Spider-Man: India (2004) #3
# Spider-Man: India (2004 - 2005)  (2004 - 2005)  Spider-Man: India (2004) #2
# Spider-Man: India (2004 - 2005)  (2004 - 2005)  Spider-Man: India (2004) #1
#
#                                       publish_date  \
# comic_name
# Spider-Man: India (2004 - 2005)  February 23, 2005
# Spider-Man: India (2004 - 2005)   January 19, 2005
# Spider-Man: India (2004 - 2005)  December 15, 2004
# Spider-Man: India (2004 - 2005)  November 17, 2004
#
#                                                                  issue_description  \
# comic_name
# Spider-Man: India (2004 - 2005)  When Pavitr Prabhakar donned the costume of Sp...
# Spider-Man: India (2004 - 2005)  Young Pavitr Prabhakar faces his first super-v...
# ...

# %%
spclan= marvel.iloc[23562:23567]
spclan['Price']='$2.25'
spclan

spclan2003 = spclan.iloc[0:4]
spclan2003

spclan2002 = spclan[4:]
spclan2002
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                              active_years  \
# comic_name
# Spider-Man: Legend of the Spider-Clan (2002)       (2002)
#
#                                                                                   issue_title  \
# comic_name
# Spider-Man: Legend of the Spider-Clan (2002)  Spider-Man: Legend of the Spider-Clan (2002) #1
#
#                                                    publish_date  \
# comic_name
# Spider-Man: Legend of the Spider-Clan (2002)  December 01, 2002
#
#                                                                               issue_description  \
# ...

# %%
lifeline= marvel.iloc[23574:23577]
lifeline['Price']='$2.99'
lifeline
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             active_years                     issue_title  \
# comic_name
# Spider-Man: Lifeline (2001)       (2001)  Spider-Man: Lifeline (2001) #3
# Spider-Man: Lifeline (2001)       (2001)  Spider-Man: Lifeline (2001) #2
# Spider-Man: Lifeline (2001)       (2001)  Spider-Man: Lifeline (2001) #1
#
#                                publish_date issue_description penciler writer  \
# comic_name
# Spider-Man: Lifeline (2001)   June 01, 2001              None     None   None
# Spider-Man: Lifeline (2001)    May 01, 2001              None     None   None
# ...

# %%
onemoreday= marvel.iloc[23580:23581]
onemoreday['Price']='$2.99'
onemoreday
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                            active_years  \
# comic_name
# SPIDER-MAN: ONE MORE DAY SKETCHBOOK (2007)       (2007)
#
#                                                                               issue_title  \
# comic_name
# SPIDER-MAN: ONE MORE DAY SKETCHBOOK (2007)  SPIDER-MAN: ONE MORE DAY SKETCHBOOK (2007) #1
#
#                                                publish_date  \
# comic_name
# SPIDER-MAN: ONE MORE DAY SKETCHBOOK (2007)  August 29, 2007
#
#                                                                             issue_description  \
# comic_name
# ...

# %%
hunter= marvel.iloc[23581:23582]
hunter
# Out:
#                                         active_years  \
# comic_name
# Spider-Man: Origin of the Hunter (2010)       (2010)
#
#                                                                         issue_title  \
# comic_name
# Spider-Man: Origin of the Hunter (2010)  Spider-Man: Origin of the Hunter (2010) #1
#
#                                            publish_date  \
# comic_name
# Spider-Man: Origin of the Hunter (2010)  April 14, 2010
#
#                                                                          issue_description  \
# comic_name
# Spider-Man: Origin of the Hunter (2010)  You know them as the sinister masterminds behi...
#
#                                                          penciler  \
# comic_name
# Spider-Man: Origin of the Hunter (2010)  Steve Ditko, Mike Mayhew
#
#                                                             writer  \
# comic_name
# Spider-Man: Origin of the Hunter (2010)  Marc Guggenheim, Stan Lee
#
# ...

# %%
quality= marvel.iloc[23582:23583]
quality['Price']= '$2.99'
quality
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                   active_years issue_title  \
# comic_name
# Spider-Man: Quality of Life (2002 - Present)  (2002 - Present)        None
#
#                                              publish_date issue_description  \
# comic_name
# Spider-Man: Quality of Life (2002 - Present)         None              None
#
#                                              penciler writer cover_artist  \
# comic_name
# Spider-Man: Quality of Life (2002 - Present)     None   None         None
#
#                                              Imprint Format Rating  Price
# comic_name
# ...

# %%
redemption= marvel.iloc[23584:23588]
redemption['Price']='$1.50'
redemption
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               active_years                       issue_title  \
# comic_name
# Spider-Man: Redemption (1996)       (1996)  Spider-Man: Redemption (1996) #4
# Spider-Man: Redemption (1996)       (1996)  Spider-Man: Redemption (1996) #3
# Spider-Man: Redemption (1996)       (1996)  Spider-Man: Redemption (1996) #2
# Spider-Man: Redemption (1996)       (1996)  Spider-Man: Redemption (1996) #1
#
#                                      publish_date  \
# comic_name
# Spider-Man: Redemption (1996)   December 01, 1996
# Spider-Man: Redemption (1996)   November 01, 1996
# ...

# %%
reign= marvel.iloc[23588:23593]
reign2007 = reign.iloc[0:4]
reign2007
reign2006 = reign.iloc[4:]
reign2006
# Out:
#                                   active_years                  issue_title  \
# comic_name
# Spider-Man: Reign (2006 - 2007)  (2006 - 2007)  Spider-Man: Reign (2006) #1
#
#                                       publish_date  \
# comic_name
# Spider-Man: Reign (2006 - 2007)  December 06, 2006
#
#                                                                  issue_description  \
# comic_name
# Spider-Man: Reign (2006 - 2007)  A searing vision of Spider-Man's future, broug...
#
#                                       penciler         writer cover_artist  \
# comic_name
# Spider-Man: Reign (2006 - 2007)  Kaare Andrews  Kaare Andrews         None
#
#                                          Imprint  Format Rating   Price
# comic_name
# Spider-Man: Reign (2006 - 2007)   MARVEL KNIGHTS   Comic      T   $3.99

# %%
goblin= marvel.iloc[23594:23597]
goblin['Price']='$2.99'
goblin
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                active_years  \
# comic_name
# Spider-Man: Revenge of the Green Goblin (2000)       (2000)
# Spider-Man: Revenge of the Green Goblin (2000)       (2000)
# Spider-Man: Revenge of the Green Goblin (2000)       (2000)
#
#                                                                                       issue_title  \
# comic_name
# Spider-Man: Revenge of the Green Goblin (2000)  Spider-Man: Revenge of the Green Goblin (2000) #3
# Spider-Man: Revenge of the Green Goblin (2000)  Spider-Man: Revenge of the Green Goblin (2000) #2
# ...

# %%
season= marvel.iloc[23598:23599]
season
# Out:
#                               active_years                       issue_title  \
# comic_name
# Spider-Man: Season One (2011)       (2011)  Spider-Man: Season One (2011) #1
#
#                                publish_date  \
# comic_name
# Spider-Man: Season One (2011)  May 09, 2012
#
#                                                                issue_description  \
# comic_name
# Spider-Man: Season One (2011)  Marvel: Season One is a new initiative aimed a...
#
#                                    penciler       writer  cover_artist  \
# comic_name
# Spider-Man: Season One (2011)  Neil Edwards  Cullen Bunn  Neil Edwards
#
#                               Imprint  Format Rating    Price
# comic_name
# Spider-Man: Season One (2011)    None   Comic   None   $24.99

# %%
swing= marvel.iloc[23605:23606]
swing
# Out:
#                                               active_years  \
# comic_name
# Spider-Man: Swing Shift Director's Cut (2008)       (2008)
#
#                                                                                     issue_title  \
# comic_name
# Spider-Man: Swing Shift Director's Cut (2008)  Spider-Man: Swing Shift Director's Cut (2008) #1
#
#                                                    publish_date  \
# comic_name
# Spider-Man: Swing Shift Director's Cut (2008)  January 30, 2008
#
#                                                                                issue_description  \
# comic_name
# Spider-Man: Swing Shift Director's Cut (2008)  Fan-favorite writer Dan Slott (AVENGERS: THE I...
#
#                                                    penciler     writer  \
# comic_name
# Spider-Man: Swing Shift Director's Cut (2008)  Phil Jimenez  Dan Slott
#
#                                                cover_artist           Imprint  \
# comic_name
# ...

# %%
clonesaga= marvel.iloc[23607:23614]
clonesaga
clonesaga2010= clonesaga.iloc[0:3]
clonesaga2010
clonesaga2009= clonesaga.iloc[3:]
clonesaga2010
# Out:
#                                            active_years  \
# comic_name
# Spider-Man: The Clone Saga (2009 - 2010)  (2009 - 2010)
# Spider-Man: The Clone Saga (2009 - 2010)  (2009 - 2010)
# Spider-Man: The Clone Saga (2009 - 2010)  (2009 - 2010)
#
#                                                                    issue_title  \
# comic_name
# Spider-Man: The Clone Saga (2009 - 2010)  Spider-Man: The Clone Saga (2009) #6
# Spider-Man: The Clone Saga (2009 - 2010)  Spider-Man: The Clone Saga (2009) #6
# Spider-Man: The Clone Saga (2009 - 2010)  Spider-Man: The Clone Saga (2009) #5
#
#                                                publish_date  \
# comic_name
# Spider-Man: The Clone Saga (2009 - 2010)  February 24, 2010
# Spider-Man: The Clone Saga (2009 - 2010)  February 24, 2010
# Spider-Man: The Clone Saga (2009 - 2010)   January 27, 2010
#
#                                                                           issue_description  \
# comic_name
# ...

# %%
finalad= marvel.iloc[23614:23618]
finalad['Price']='$2.95'
finalad
finalad1996 = finalad.iloc[0:3]
finalad1996
finalad1995 = finalad.iloc[3:]
finalad1996
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 active_years  \
# comic_name
# Spider-Man: The Final Adventure (1995 - 1996)  (1995 - 1996)
# Spider-Man: The Final Adventure (1995 - 1996)  (1995 - 1996)
# Spider-Man: The Final Adventure (1995 - 1996)  (1995 - 1996)
#
#                                                                              issue_title  \
# comic_name
# Spider-Man: The Final Adventure (1995 - 1996)  Spider-Man: The Final Adventure (1995) #4
# Spider-Man: The Final Adventure (1995 - 1996)  Spider-Man: The Final Adventure (1995) #3
# ...

# %%
gauntlet= marvel.iloc[23619:23620]
gauntlet
# Out:
#                                                    active_years  \
# comic_name
# Spider-Man: The Gauntlet Vol. 3 - Vulture and M...       (2010)
#
#                                                                                           issue_title  \
# comic_name
# Spider-Man: The Gauntlet Vol. 3 - Vulture and M...  Spider-Man: The Gauntlet Vol. 3 - Vulture and ...
#
#                                                     publish_date  \
# comic_name
# Spider-Man: The Gauntlet Vol. 3 - Vulture and M...  May 19, 2010
#
#                                                                                     issue_description  \
# comic_name
# Spider-Man: The Gauntlet Vol. 3 - Vulture and M...  The Vulture must feed! That savage menace of t...
#
#                                                    penciler writer  \
# comic_name
# Spider-Man: The Gauntlet Vol. 3 - Vulture and M...     None   None
#
#                                                    cover_artist Imprint  \
# comic_name
# ...

# %%
osbornjournal= marvel.iloc[23624:23625]
osbornjournal['Price']='$2.95'
osbornjournal
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       active_years  \
# comic_name
# Spider-Man: The Osborn Journal (1996)       (1996)
#
#                                                                     issue_title  \
# comic_name
# Spider-Man: The Osborn Journal (1996)  Spider-Man: The Osborn Journal (1996) #1
#
#                                             publish_date  \
# comic_name
# Spider-Man: The Osborn Journal (1996)  December 18, 1996
#
#                                                                        issue_description  \
# comic_name
# ...

# %%
spidtheother= marvel.iloc[23625:23626]
spidtheother
# Out:
#                                         active_years  \
# comic_name
# Spider-Man: The Other Sketchbook (2005)       (2005)
#
#                                                                      issue_title  \
# comic_name
# Spider-Man: The Other Sketchbook (2005)  Spider-Man: The Other (Trade Paperback)
#
#                                              publish_date  \
# comic_name
# Spider-Man: The Other Sketchbook (2005)  October 11, 2006
#
#                                                                          issue_description  \
# comic_name
# Spider-Man: The Other Sketchbook (2005)  This deluxe hardcover collects the startling s...
#
#                                         penciler writer cover_artist  \
# comic_name
# Spider-Man: The Other Sketchbook (2005)     None   None         None
#
#                                                   Imprint            Format  \
# comic_name
# Spider-Man: The Other Sketchbook (2005)   MARVEL UNIVERSE   Trade Paperback
#
# ...

# %%
ParkerY= marvel.iloc[23627:23628]
ParkerY['Price']= '$2.95'
ParkerY
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                     active_years  \
# comic_name
# Spider-Man: The Parker Years (1995)       (1995)
#
#                                                                 issue_title  \
# comic_name
# Spider-Man: The Parker Years (1995)  Spider-Man: The Parker Years (1995) #1
#
#                                           publish_date  \
# comic_name
# Spider-Man: The Parker Years (1995)  November 01, 1995
#
#                                                                      issue_description  \
# comic_name
# ...

# %%
shorthall= marvel.iloc[23628:23629]
shorthall
# Out:
#                                        active_years  \
# comic_name
# Spider-Man: The Short Halloween (2009)       (2009)
#
#                                                                       issue_title  \
# comic_name
# Spider-Man: The Short Halloween (2009)  Spider-Man: The Short Halloween (2009) #1
#
#                                         publish_date  \
# comic_name
# Spider-Man: The Short Halloween (2009)  May 28, 2009
#
#                                                                         issue_description  \
# comic_name
# Spider-Man: The Short Halloween (2009)  Two stars of Saturday Night Live make their Ma...
#
#                                              penciler  \
# comic_name
# Spider-Man: The Short Halloween (2009)  Kevin Maguire
#
#                                                          writer cover_artist  \
# comic_name
# Spider-Man: The Short Halloween (2009)  Bill Hader, Seth Meyers         None
#
# ...

# %%
venomagen= marvel.iloc[23630:23631]
venomagen['Price']='$2.99'
venomagen
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                     active_years  \
# comic_name
# Spider-Man: The Venom Agenda (1998)       (1998)
#
#                                                                 issue_title  \
# comic_name
# Spider-Man: The Venom Agenda (1998)  Spider-Man: The Venom Agenda (1998) #1
#
#                                          publish_date  \
# comic_name
# Spider-Man: The Venom Agenda (1998)  January 01, 1998
#
#                                                                      issue_description  \
# comic_name
# ...

# %%
greatpo= marvel.iloc[23631:23638]
greatpo
# Out:
#                                                      active_years  \
# comic_name
# Spider-Man: With Great Power Comes Great Respon...  (2010 - 2011)
# Spider-Man: With Great Power Comes Great Respon...  (2010 - 2011)
# Spider-Man: With Great Power Comes Great Respon...  (2010 - 2011)
# Spider-Man: With Great Power Comes Great Respon...  (2010 - 2011)
# Spider-Man: With Great Power Comes Great Respon...  (2010 - 2011)
# Spider-Man: With Great Power Comes Great Respon...  (2010 - 2011)
# Spider-Man: With Great Power Comes Great Respon...  (2010 - 2011)
#
#                                                                                           issue_title  \
# comic_name
# Spider-Man: With Great Power Comes Great Respon...  Spider-Man: With Great Power Comes Great Respo...
# Spider-Man: With Great Power Comes Great Respon...  Spider-Man: With Great Power Comes Great Respo...
# Spider-Man: With Great Power Comes Great Respon...  Spider-Man: With Great Power Comes Great Respo...
# ...

# %%
Greatpo2008= marvel.iloc[23638:23643]
Greatpo2008
# Out:
#                                        active_years  \
# comic_name
# Spider-Man: With Great Power... (2008)       (2008)
# Spider-Man: With Great Power... (2008)       (2008)
# Spider-Man: With Great Power... (2008)       (2008)
# Spider-Man: With Great Power... (2008)       (2008)
# Spider-Man: With Great Power... (2008)       (2008)
#
#                                                                       issue_title  \
# comic_name
# Spider-Man: With Great Power... (2008)  Spider-Man: With Great Power... (2008) #5
# Spider-Man: With Great Power... (2008)  Spider-Man: With Great Power... (2008) #4
# Spider-Man: With Great Power... (2008)  Spider-Man: With Great Power... (2008) #3
# Spider-Man: With Great Power... (2008)  Spider-Man: With Great Power... (2008) #2
# Spider-Man: With Great Power... (2008)  Spider-Man: With Great Power... (2008) #1
#
#                                              publish_date  \
# comic_name
# Spider-Man: With Great Power... (2008)      July 30, 2008
# ...

# %%
hired= marvel.iloc[23643:23644]
hired
# Out:
#                                  active_years  \
# comic_name
# Spider-Man: You're Hired! (2011)       (2011)
#
#                                                           issue_title  \
# comic_name
# Spider-Man: You're Hired! (2011)  Spider-Man: You're Hired! (2011) #1
#
#                                     publish_date  \
# comic_name
# Spider-Man: You're Hired! (2011)  March 30, 2011
#
#                                                                   issue_description  \
# comic_name
# Spider-Man: You're Hired! (2011)  Spidey teams up with Mayor Bloomberg, and it's...
#
#                                                                  penciler  \
# comic_name
# Spider-Man: You're Hired! (2011)  Reilly Brown, Todd Nauck, Clayton Henry
#
#                                                       writer cover_artist  \
# comic_name
# Spider-Man: You're Hired! (2011)  Paul Tobin, Fred Van Lente   Dale Keown
#
#                                  Imprint  Format Rating   Price
# ...

# %%
spidPParker= marvel.iloc[19599:19604]
spidPParker
# Out:
#                                 active_years  \
# comic_name
# Peter Parker, Spider-Man (2012)       (2012)
# Peter Parker, Spider-Man (2012)       (2012)
# Peter Parker, Spider-Man (2012)       (2012)
# Peter Parker, Spider-Man (2012)       (2012)
# Peter Parker, Spider-Man (2012)       (2012)
#
#                                                             issue_title  \
# comic_name
# Peter Parker, Spider-Man (2012)      Peter Parker, Spider-Man (2012) #5
# Peter Parker, Spider-Man (2012)      Peter Parker, Spider-Man (2012) #4
# Peter Parker, Spider-Man (2012)      Peter Parker, Spider-Man (2012) #3
# Peter Parker, Spider-Man (2012)      Peter Parker, Spider-Man (2012) #2
# Peter Parker, Spider-Man (2012)  Peter Parker, Spider-Man (2012) #156.1
#
#                                     publish_date  \
# comic_name
# Peter Parker, Spider-Man (2012)  August 29, 2012
# Peter Parker, Spider-Man (2012)  August 22, 2012
# Peter Parker, Spider-Man (2012)  August 15, 2012
# ...

# %%
ppSpcspide= marvel.iloc[19612:19656]
ppSpcspide1998 = ppSpcspide.iloc[0:11]
ppSpcspide1998['Price']='$1.99'
ppSpcspide1998
ppSpcspide1997 = ppSpcspide.iloc[11:22]
ppSpcspide1997['Price']='$1.99'
ppSpcspide1997
ppSpcspide1996 = ppSpcspide.iloc[22:34]
ppSpcspide1996['Price']='$1.50'
ppSpcspide1996
ppSpcspide1995 = ppSpcspide.iloc[34:]
ppSpcspide1995['Price']='$1.50'
#ppSpcspide1996
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# ...

# %%
spideyPeter11= marvel.iloc[19883:19948]
spideyPeter1 = spideyPeter11.iloc[0:4]
spideyPeter1
spideyPeter2 = spideyPeter11.iloc[5:8]
spideyPeter2
spideyPeter3 = spideyPeter11.iloc[9:49]
spideyPeter3
spideyPeter4 = spideyPeter11.iloc[54:]
spideyPeter4

spiderPeter= pd.concat([spideyPeter1, spideyPeter2, spideyPeter3, spideyPeter4])
spiderPeter['Price']='$2.99'
spiderPeter2003 = spiderPeter.iloc[0:8]
spiderPeter2003
spiderPeter2002= spiderPeter.iloc[8:22]
spiderPeter2002
spiderPeter2001= spiderPeter.iloc[22:34]
spiderPeter2001
spiderPeter2000= spiderPeter.iloc[34:46]
spiderPeter2000 
spiderPeter1999= spiderPeter.iloc[46:]
#spiderPeter

# %%
Theamazingspid= marvel.iloc[26080:26125]
Theamazingspid['Price']='$1.99'
Theamazingspid

Theamazingspid1998 = Theamazingspid.iloc[0:12]
Theamazingspid1998
Theamazingspid1997 = Theamazingspid.iloc[12:23]
Theamazingspid1997
Theamazingspid1996= Theamazingspid.iloc[23:35]
Theamazingspid1996
Theamazingspid1995 = Theamazingspid.iloc[35:]

Theamazingspid1995
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                        active_years  \
# comic_name
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# The Amazing Spider-Man (1963 - 1998)  (1963 - 1998)
# ...

# %%
ultimate200= marvel.iloc[29543:29709]
ultimate2 = ultimate200.iloc[2:5]
ultimate2
ultimate3 = ultimate200.iloc[6:12]
ultimate3
ultimate4 = ultimate200.iloc[13:19]
ultimate4
ultimate5 = ultimate200.iloc[21:26]
ultimate5
ultimate6 = ultimate200.iloc[29:30]
ultimate6
ultimate7 = ultimate200.iloc[31:42]
ultimate7['Price']='$2.99'
ultimate7
ultimate8 = ultimate200.iloc[43:48]
ultimate8
ultimate9 = ultimate200.iloc[49:55]
ultimate9
ultimate10 = ultimate200.iloc[56:66]
ultimate10
ultimate11 = ultimate200.iloc[65:66]
ultimate11
ultimate12 = ultimate200.iloc[67:69]
ultimate12
ultimate13= ultimate200.iloc[71:74]
ultimate13
ultimate14 = ultimate200[75:81]
ultimate14
ultimate15 = ultimate200[82:92]
ultimate15 
ultimate16 = ultimate200.iloc[93:105]
ultimate16
ultimate17 = ultimate200.iloc[105:110]
ultimate17['Price']='$2.25'
ultimate17
ultimate18 = ultimate200.iloc[111:113]
ultimate18['Price']='$2.25'
ultimate18
ultimate19= ultimate200.iloc[114:121]
ultimate19['Price']='$2.25'
ultimate19
ultimate20 = ultimate200.iloc[122:127]
ultimate20['Price']='$2.25'
ultimate20
ultimate21 = ultimate200.iloc[128:130]
ultimate21
ultimate22 = ultimate200.iloc[131:156]
ultimate22
ultimatepri = pd.concat([ultimate2, ultimate3, ultimate4, ])
ultimatepri

ultimateseg = pd.concat([ultimate5, ultimate6, ultimate7])
ultimateseg

ultimateter = pd.concat([ultimate8, ultimate9, ultimate10, ultimate11, ultimate12])
ultimateter

ultimatecuar= pd.concat([ultimate13,ultimate14, ultimate15, ultimate16])
ultimatecuar

ultimatecinc= pd.concat([ultimate17, ultimate18, ultimate19, ultimate20, ultimate21, ultimate22])
ultimatecinc

defiultimate = pd.concat([ultimatepri, ultimateseg, ultimateter, ultimatecuar, ultimatecinc])
defiultimate

ultimate2009 = defiultimate.iloc[0:4]
ultimate2009
ultimate2008 = defiultimate.iloc[4:16]
ultimate2008
ultimate2007 = defiultimate.iloc[16:28]
ultimate2007
ultimate2006= defiultimate.iloc[28:43]
ultimate2006
ultimate20055= defiultimate.iloc[44:63]
ultimate20055
ultimate2004= defiultimate.iloc[63:82]
ultimate2004
ultimate2003= defiultimate.iloc[82:104]
ultimate2003
ultimate2002= defiultimate.iloc[104:117]
ultimate2002['Price']='$2.25'
ultimate2002
ultimate2001= defiultimate.iloc[117:129]
ultimate2001['Price']='$2.25'
ultimate2001
ultimate2000= defiultimate.iloc[129:]
ultimate2000['Price']='$3.99'

ultimate20051=  ultimate20055[0:5]
ultimate20051
ultimate20052 = ultimate20055.iloc[6:7]
ultimate20052

ultimate20053 = ultimate20055.iloc[8:]
ultimate20053
ultimate2005 = pd.concat([ultimate20051, ultimate20052, ultimate20053])
#ultimate2005
#ultimate2009
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Unión de los diferentes Dataframe en cada año desde 1995 hasta 2012

# %%
df_1995 = pd.concat([spiderman1995, spid20991995, espe2099, spidTeamup1995, finalad1995, ParkerY, ppSpcspide1995, Theamazingspid1995 ])
df_1995['active_years']= 1995
df_1995
# Out:
#                                                     active_years  \
# comic_name
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man (1990 - 1998)                                    1995
# Spider-Man 2099 (1992 - 1996)                               1995
# Spider-Man 2099 (1992 - 1996)                               1995
# Spider-Man 2099 (1992 - 1996)                               1995
# ...

# %%
df_1996 = pd.concat([spiderman1996, spidTeamup1996, famspidpu, redemption, finalad1996, osbornjournal, ppSpcspide1996, Theamazingspid1996])
df_1996['active_years']= 1996
#df_1996

# %%
df_1997 = pd.concat([spiderman1997, spidTeamup1997,spid101, spidDMH, hobgoblin, ppSpcspide1997, Theamazingspid1997 ])
df_1997['active_years']= 1997
#df_1997

# %%
df_1998 = pd.concat([spiderman1998, chapter98, venomagen, ppSpcspide1998])
df_1998['active_years']= 1998
df_1998
# Out:
#                                                     active_years  \
# comic_name
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man (1990 - 1998)                                    1998
# Spider-Man: Chapter One (1998 - 1999)                       1998
# ...

# %%
df_1999 = pd.concat([chapter99, spiderPeter1999])
df_1999['active_years']= 1999
#df_1999

# %%
df_2000 = pd.concat([spidvspu, spidDDes, goblin, spiderPeter2000, ultimate2000])
df_2000['active_years']= 2000
#df_2000

# %%
df_2001 = pd.concat([spidTW2001, lifeline, spiderPeter2000, ultimate2001])
df_2001['active_years']= 2001
#df_2001

# %%
df_2002 = pd.concat([spidTW2002, Spiddad, spidblue2002, getkraven, spclan2002, quality, ultimate2002, spBC2002])
df_2002['active_years']= 2002
#df_2002

# %%
df_2003 = pd.concat([fusion2003, spidylob, spidTW2003, octopusneg12003, spidblue2003, spclan2003, spiderPeter2003, ultimate2003])
df_2003['active_years']= 2003
#df_2003

# %%
df_2004 = pd.concat([fusion2004, spiderman2004, spidmovie2, spidunlit2004, octopusneg12004, octopusreach, OctopusY1, ultimate2004])
df_2004['active_years']= 2004
#df_2004

# %%
df_2005 = pd.concat([fusion2005, spidmj12005, teamup, spidunlit2005, spiderHT, breakout, houseM, india, ultimate2005])
df_2005['active_years']= 2005
#df_2005

# %%
df_2006 = pd.concat([aranaspecial, SpidaPP2006, spidermanff, spidmj12006, spidSPBL, reign2006, spidunlit2006, spBC2006,spidtheother,ultimate2006 ])
df_2006['active_years']= 2006
#df_2006

# %%
df_2007 = pd.concat([SpidaPP2007, spiderf4, spiderftales, spiderfamily2007, spidmj12007, peterBB, redsonja, spidBB2, onemoreday, reign2007, ultimate2007 ])
df_2007['active_years']= 2007
#df_2007

# %%
df_2008 = pd.concat([spiderfamily2008, spidmj2, spidernoir2008, brand2008, swing, Greatpo2008, ultimate2008])
df_2008['active_years']= 2008
#df_2008

# %%
df_2009 = pd.concat([spid1602b2009, Spidernoir2009, Spidernoirface2009, brand2009, fearitself, clonesaga2009, shorthall, ultimate2009])
df_2009['active_years']= 2009
#df_2009

# %%
df_2010 = pd.concat([sp2010, spid1602b2010, spiderMA2010, Spidernoirface2010, spidvamp, spiderFF2, spidBIQ, fever, kravensaga, clonesaga2010, gauntlet])
df_2010['active_years']= 2010
#df_2010

# %%
df_2011 = pd.concat([spiderMA2011, season, greatpo, hired])
df_2011['active_years']= 2011
#df_2011

# %%
df_2012 = pd.concat([spiderMA2012, spidPParker])
df_2012['active_years']= 2012
#df_2012

# %% [markdown]
# Datframe que necesito para los gráficos

# %%
antes = pd.concat([df_1995, df_1996, df_1997, df_1998, df_1999, df_2000])
antes
# Out:
#                                         active_years  \
# comic_name
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# ...                                              ...
# Peter Parker: Spider-Man (1999 - 2003)          2000
# Ultimate Spider-Man (2000 - 2009)               2000
# Ultimate Spider-Man (2000 - 2009)               2000
# Ultimate Spider-Man (2000 - 2009)               2000
# Ultimate Spider-Man (2000 - 2009)               2000
#
#                                                                 issue_title  \
# comic_name
# Spider-Man (1990 - 1998)                              Spider-Man (1990) #63
# Spider-Man (1990 - 1998)                              Spider-Man (1990) #62
# ...

# %%
durante = pd.concat([df_2001, df_2002, df_2003, df_2004, df_2005, df_2006, df_2007])
#durante

# %%
despues = pd.concat([df_2008, df_2009, df_2010, df_2011, df_2012])
despues
# Out:
#                                           active_years  \
# comic_name
# Spider-Man Family (2007 - 2008)                   2008
# Spider-Man Family (2007 - 2008)                   2008
# Spider-Man Family (2007 - 2008)                   2008
# Spider-Man Loves Mary Jane (2008 - 2009)          2008
# Spider-Man Loves Mary Jane (2008 - 2009)          2008
# ...                                                ...
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
#
#                                                                      issue_title  \
# comic_name
# Spider-Man Family (2007 - 2008)                      Spider-Man Family (2007) #9
# Spider-Man Family (2007 - 2008)                      Spider-Man Family (2007) #8
# ...

# %% [markdown]
# # Limpieza de columnas, lo hago al final antes de crear los gráficos

# %%
#antes.drop(['Rating', 'issue_description', 'Imprint'], axis='columns', inplace=True )
antes
# Out:
#                                         active_years  \
# comic_name
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# Spider-Man (1990 - 1998)                        1995
# ...                                              ...
# Peter Parker: Spider-Man (1999 - 2003)          2000
# Ultimate Spider-Man (2000 - 2009)               2000
# Ultimate Spider-Man (2000 - 2009)               2000
# Ultimate Spider-Man (2000 - 2009)               2000
# Ultimate Spider-Man (2000 - 2009)               2000
#
#                                                                 issue_title  \
# comic_name
# Spider-Man (1990 - 1998)                              Spider-Man (1990) #63
# Spider-Man (1990 - 1998)                              Spider-Man (1990) #62
# ...

# %%
#despues.drop(['Format', 'Rating', 'issue_description', 'Imprint'], axis='columns', inplace=True )
despues
# Out:
#                                           active_years  \
# comic_name
# Spider-Man Family (2007 - 2008)                   2008
# Spider-Man Family (2007 - 2008)                   2008
# Spider-Man Family (2007 - 2008)                   2008
# Spider-Man Loves Mary Jane (2008 - 2009)          2008
# Spider-Man Loves Mary Jane (2008 - 2009)          2008
# ...                                                ...
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
# Peter Parker, Spider-Man (2012)                   2012
#
#                                                                      issue_title  \
# comic_name
# Spider-Man Family (2007 - 2008)                      Spider-Man Family (2007) #9
# Spider-Man Family (2007 - 2008)                      Spider-Man Family (2007) #8
# ...

# %%
durante
# Out:
#                                         active_years  \
# comic_name
# Spider-Man's Tangled Web (2001 - 2003)          2001
# Spider-Man's Tangled Web (2001 - 2003)          2001
# Spider-Man's Tangled Web (2001 - 2003)          2001
# Spider-Man's Tangled Web (2001 - 2003)          2001
# Spider-Man's Tangled Web (2001 - 2003)          2001
# ...                                              ...
# Ultimate Spider-Man (2000 - 2009)               2007
# Ultimate Spider-Man (2000 - 2009)               2007
# Ultimate Spider-Man (2000 - 2009)               2007
# Ultimate Spider-Man (2000 - 2009)               2007
# Ultimate Spider-Man (2000 - 2009)               2007
#
#                                                                issue_title  \
# comic_name
# Spider-Man's Tangled Web (2001 - 2003)  Spider-Man's Tangled Web (2001) #7
# Spider-Man's Tangled Web (2001 - 2003)  Spider-Man's Tangled Web (2001) #6
# ...

# %%
total = pd.concat([antes, durante, despues])
total.reset_index(level=0, inplace=True)
total
# Out:
#                           comic_name  active_years  \
# 0           Spider-Man (1990 - 1998)          1995
# 1           Spider-Man (1990 - 1998)          1995
# 2           Spider-Man (1990 - 1998)          1995
# 3           Spider-Man (1990 - 1998)          1995
# 4           Spider-Man (1990 - 1998)          1995
# ..                               ...           ...
# 632  Peter Parker, Spider-Man (2012)          2012
# 633  Peter Parker, Spider-Man (2012)          2012
# 634  Peter Parker, Spider-Man (2012)          2012
# 635  Peter Parker, Spider-Man (2012)          2012
# 636  Peter Parker, Spider-Man (2012)          2012
#
#                                 issue_title        publish_date  \
# 0                     Spider-Man (1990) #63    October 01, 1995
# 1                     Spider-Man (1990) #62  September 01, 1995
# 2                     Spider-Man (1990) #61     August 01, 1995
# 3                     Spider-Man (1990) #60       July 01, 1995
# ...

# %%
#total['Price']= total['Price'].str.replace('$',"")
#total['Price']= total['Price'].str.replace(',', '.')
#total['Total']= total['Price'].astype(float)
#total

#total['active_years'] = total['active_years'].astype(float) 
#total

#total.drop(['Format', 'Rating', 'issue_description', 'Imprint', ], axis='columns', inplace=True )
#total

#total.rename(columns={'Price':'PriceDollar'}, inplace=True)
#total

total.drop(['Total'], axis='columns', inplace=True)
total
# Out:
#                           comic_name  active_years  \
# 0           Spider-Man (1990 - 1998)        1995.0
# 1           Spider-Man (1990 - 1998)        1995.0
# 2           Spider-Man (1990 - 1998)        1995.0
# 3           Spider-Man (1990 - 1998)        1995.0
# 4           Spider-Man (1990 - 1998)        1995.0
# ..                               ...           ...
# 632  Peter Parker, Spider-Man (2012)        2012.0
# 633  Peter Parker, Spider-Man (2012)        2012.0
# 634  Peter Parker, Spider-Man (2012)        2012.0
# 635  Peter Parker, Spider-Man (2012)        2012.0
# 636  Peter Parker, Spider-Man (2012)        2012.0
#
#                                 issue_title        publish_date  \
# 0                     Spider-Man (1990) #63    October 01, 1995
# 1                     Spider-Man (1990) #62  September 01, 1995
# 2                     Spider-Man (1990) #61     August 01, 1995
# 3                     Spider-Man (1990) #60       July 01, 1995
# ...

# %% [markdown]
# # Creación de  graficos que voy a usar para la presentación

# %%
import numpy as np 
import seaborn as sns
import plotly.express as px


from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go


from wordcloud import WordCloud


import matplotlib.pyplot as plt


import os
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plt.figure(figsize=(10,5))
sns.distplot(total["active_years"],
             kde=False,
             color='g',
             bins=100)
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='active_years'>

# %%
plt.figure(figsize=(8,8))
sns.distplot(total["active_years"],
             kde=False,
             color='Blue',
             bins=10)
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='active_years'>

# %%
plt.figure(figsize=(8,8))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%')
p=plt.gcf();

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=total['active_years'],
                y=total['PriceDollar'],
                hue = total['PriceDollar'],
                 );

# %%
plt.figure(figsize=(5,5))
sns.distplot(total["PriceDollar"],
             kde=False,
             color='Yellow',
             bins=5)
# Out:
# c:\Users\lopez\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# <AxesSubplot:xlabel='PriceDollar'>

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=total,
             x="PriceDollar",
             y="active_years",
             hue="active_years",
            linewidth = 5);

# %%
trace1 = go.Scatter(
                    x = total.active_years,
                    y = total.PriceDollar ,
                    mode = "lines+markers",
                    name = "Comics",
                    marker = dict(color = 'rgba(0, 199, 15, .5)'),
                    text = total.comic_name)



data = [trace1]
layout = {'title':'Spiderman Comics',
            'xaxis':{'title':'años','ticklen':5}, 
                                                              }

fig = go.Figure({'data':data, 'layout':layout})



iplot(fig)
fig.write_html("C:\\Users\\lopez\\OneDrive\\Escritorio\\CTBPush\\TheBrigde2022\\2-Data Analysis\\Proyecto-EDA\\Ejemplos\\Precio1.html")
# Out:
# <div>                            <div id="ac55a046-eb64-4d89-9014-9e974aea1cea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac55a046-eb64-4d89-9014-9e974aea1cea")) {                    Plotly.newPlot(                        "ac55a046-eb64-4d89-9014-9e974aea1cea",                        [{"marker":{"color":"rgba(0, 199, 15, .5)"},"mode":"lines+markers","name":"Comics","text":["Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man 2099 (1992 - 1996)","Spider-Man 2099 (1992 - 1996)","Spider-Man 2099 (1992 - 1996)","Spider-Man
# ...

# %%
trace1 = go.Scatter(
                    x = total.active_years,
                    y = total.writer ,
                    mode = "lines+markers",
                    name = "Writer",
                    marker = dict(color = 'rgba(225, 224, 51, .5)'),
                    text = total.comic_name)

trace2 = go.Scatter(
                    x = total.active_years,
                    y = total.penciler ,
                    mode = "lines+markers",
                    name = "Penciler",
                    marker = dict(color = 'rgba(51, 97, 255, .5)'),
                    text = total.comic_name)


data = [trace1,trace2]
layout = {'title':'Spiderman Comics',
            'xaxis':{'title':'Autores','ticklen':5}, 
                                                              }

fig = go.Figure({'data':data, 'layout':layout})



iplot(fig)
fig.write_html("C:\\Users\\lopez\\OneDrive\\Escritorio\\CTBPush\\TheBrigde2022\\2-Data Analysis\\Proyecto-EDA\\Ejemplos\\file.html")
# Out:
# <div>                            <div id="e5a4f672-638e-4a9c-88e4-0c58e0b94798" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5a4f672-638e-4a9c-88e4-0c58e0b94798")) {                    Plotly.newPlot(                        "e5a4f672-638e-4a9c-88e4-0c58e0b94798",                        [{"marker":{"color":"rgba(225, 224, 51, .5)"},"mode":"lines+markers","name":"Writer","text":["Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man (1990 - 1998)","Spider-Man 2099 (1992 - 1996)","Spider-Man 2099 (1992 - 1996)","Spider-Man 2099 (1992 - 1996)","Spider-M
# ...
